# %% [markdown]
# # Validação inicial: GitHub → Colab → Google Drive → ImageLoader
#
# Este notebook valida a infraestrutura inicial do projeto sem montar o Drive pessoal do aluno. As imagens são baixadas da pasta pública da disciplina.

# %% [markdown]
# # Instalar o projeto

# %%
# %pip install -q "git+https://github.com/tfvieira/dip-2026-2.git"

# %% [markdown]
# # Baixar e carregar a imagem

# %%
from dip_toolkit import download_course_image
from dip_toolkit.modules.image_loader import ImageLoader

image_path = download_course_image(
    "cameraman_original.png",
    output_dir="/content/dip_images",
)

image = ImageLoader().load_image(image_path)

print("Caminho:", image_path)
print("Formato:", image.shape)
print("Tipo:", image.dtype)

# %% [markdown]
# # Exibir

# %%
import cv2
import matplotlib.pyplot as plt

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(7, 7))
plt.imshow(image_rgb)
plt.axis("off")
plt.show()
